# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
import requests

url = "https://www.jumia.com.ng/mlp-stay-connected-deals/smartphones/"
page = requests.get(url)
soup = bs(page.content, "html5lib")
#rint(soup.prettify())
table = soup.find("div", attrs={'class':'-paxs row _no-g _4cl-3cm-shs'})
print(table.prettify())
articles = table.findAll("article", attrs={"class":"prd _fb col c-prd"})
#print(articles[1].prettify())
#items[]
#   df = pd.DataFrame(columns=["name","discounted_price","original_price","discount","rating"])
for phone in articles:
    item = {}
    item['name'] = phone.find("h3", attrs={"class": "name"}).text
    item["discounted_price"] = phone.find("div", attrs={"class": "prc"}).text
    item["original_price"] = phone.find("div", attrs={"class": "old"}).text
    item["discount"] = phone.find("div", attrs={"class": "bdg _dsct _sm"}).text
    rating =phone.find("div",class_="stars _s")
    if rating is not None:
        item["rating"] = rating.contents[0]
    else:
        item["rating"] = ""
    df = df.append(item, ignore_index=True)
#df.head
df.to_csv("jumia_phone_data.csv")
print("End")
# Out:
# <div class="-paxs row _no-g _4cl-3cm-shs" data-catalog="true">
#  <article class="prd _fb col c-prd">
#   <a class="core" data-brand="itel" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="407180" data-dimension26="44" data-dimension27="4.2" data-dimension28="1" data-dimension37="0" data-dimension43="CP_13|CP_UN97|FDYJE|JF23|JF23_01|JMALL|TBOOST" data-dimension44="0" data-id="IT724MP4792ZMNAFAMZ" data-list="" data-name='P40 6.6" 4GB RAM/64GB ROM Android 12 - Blue' data-position="1" data-price="62.90" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/itel-p40-6.6-4gb-ram64gb-rom-android-12-blue-249754045.html">
#    <div class="img-c">
#     <img alt="" class="img" data-lazy="true" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/54/0457942/1.jpg?5437" height="208" src="..." width="208"/>
#     <span class="bdg _xs camp" style="color:#FFFFFF;background:#B177DA;">
#      Brand Festival Deal
#     </span>
#    </div>
#    <div class="info">
#     <div class="bdg _mall _xs">
#      Official Store
#     </div>
#     <h3 class="name">
#      itel P40 6.6" 4GB RAM/64GB ROM Android 12 - Blue
#     </h3>
#     <div class="prc">
#      ₦ 52,900
#     </div>
#     <div class="s-prc-w">
#      <div class="old">
#       ₦ 68,500
#      </div>
#      <div class="bdg _dsct _sm">
#       23%
#      </div>
#     </div>
#     <div class="rev">
#      <div class="stars _s">
#       4.2 out of 5
#       <div class="in" style="width:84%">
#       </div>
#      </div>
#      (44)
#     </div>
#     <svg aria-label="Express Shipping" class="ic xprss" height="10" viewBox="0 0 114 12" width="94">
#      <use xlink:href="https://www.jumia.com.ng/assets_he/images/i-shop-jumia.9f5451c7.svg#express">
#      </use>
#     </svg>
#    </div>
#   </a>
#   <footer class="ft">
#    <form action="/cart/products/IT724MP4792ZMNAFAMZ-378676654/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="itel" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="407180" data-dimension26="44" data-dimension27="4.2" data-dimension28="1" data-dimension37="0" data-dimension43="CP_13|CP_UN97|FDYJE|JF23|JF23_01|JMALL|TBOOST" data-dimension44="0" data-id="IT724MP4792ZMNAFAMZ" data-name='P40 6.6" 4GB RAM/64GB ROM Android 12 - Blue' data-price="62.90" data-simplesku="IT724MP4792ZMNAFAMZ-378676654" data-sku="IT724MP4792ZMNAFAMZ" data-svar="IT724MP4792ZMNAFAMZ-378676654" data-track-onsubmit="addToCart" data-variant="" data-xhr="true" method="post">
#     <button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">
#      Add To Cart
#     </button>
#     <input name="csrfToken" type="hidden" value="cafd37c74006eac76fb94a073c1aa87f"/>
#    </form>
#   </footer>
#  </article>
#  <article class="prd _fb col c-prd">
#   <a class="core" data-brand="Infinix" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="362095" data-dimension26="140" data-dimension27="4.3" data-dimension28="1" data-dimension37="0" data-dimension43="Boost|CP_13|CP_MT149|CP_MT150|CP_UN97|FDYJE|JF23|JF23_01|JMALL|TBOOST|XTR250" data-dimension44="0" data-id="IN717MP4JJ398NAFAMZ" data-list="" data-name='HOT 30i 6.56" 4GB RAM/128GB ROM Android 12 - Black' data-position="2" data-price="110.58" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/infinix-hot-30i-6.56-4gb-ram128gb-rom-android-12-black-229086647.html">
#    <div class="img-c">
#     <img alt="" class="img" data-lazy="true" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/74/6680922/1.jpg?8022" height="208" src="..." width="208"/>
#     <span class="bdg _xs camp" style="color:#FFFFFF;background:#B177DA;">
#      Brand Festival Deal
#     </span>
#    </div>
#    <div class="info">
#     <div class="bdg _mall _xs">
#      Official Store
#     </div>
#     <h3 class="name">
#      Infinix HOT 30i 6.56" 4GB RAM/128GB ROM Android 12 - Black
#     </h3>
#     <div class="prc">
#      ₦ 93,000
#     </div>
#     <div class="s-prc-w">
#      <div class="old">
#       ₦ 180,300
#      </div>
#      <div class="bdg _dsct _sm">
#       48%
#      </div>
#     </div>
#     <div class="rev">
#      <div class="stars _s">
#       4.3 out of 5
#       <div class="in" style="width:86%">
#       </div>
#      </div>
#      (140)
#     </div>
#     <svg aria-label="Express Shipping" class="ic xprss" height="10" viewBox="0 0 114 12" width="94">
#      <use xlink:href="https://www.jumia.com.ng/assets_he/images/i-shop-jumia.9f5451c7.svg#express">
#      </use>
#     </svg>
#    </div>
#   </a>
#   <footer class="ft">
#    <div class="-df -i-ctr -pr -j-bet" data-add-cart="" data-sku="IN717MP4JJ398NAFAMZ" data-svar="IN717MP4JJ398NAFAMZ-351542744" data-xhr="true">
#     <button class="add btn _prim -pea _md" data-trigpopup="" type="button">
#      Add To Cart
#     </button>
#    </div>
#   </footer>
#  </article>
#  <article class="prd _fb col c-prd">
#   <a class="core" data-brand="XIAOMI" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="335380" data-dimension26="17" data-dimension27="4.2" data-dimension28="1" data-dimension37="0" data-dimension43="CP_13|FDYJE|JF23|JF23_01|JMALL" data-dimension44="0" data-id="XI363MP3TS0D7NAFAMZ" data-list="" data-name='Redmi 12 6.79" 8GB RAM/256 GB ROM Android 13-Midnight Black' data-position="3" data-price="146.48" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/xiaomi-redmi-12-6.79-8gb-ram256-gb-rom-android-13-midnight-black-253241413.html">
#    <div class="img-c">
#     <img alt="" class="img" data-lazy="true" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/31/4142352/1.jpg?0794" height="208" src="..." width="208"/>
#     <span class="bdg _xs camp" style="color:#FFFFFF;background:#B177DA;">
#      Brand Festival Deal
#     </span>
#    </div>
#    <div class="info">
#     <div class="bdg _mall _xs">
#      Official Store
#     </div>
#     <h3 class="name">
#      XIAOMI Redmi 12 6.79" 8GB RAM/256 GB ROM Android 13-Midnight Black
#     </h3>
#     <div class="prc">
#      ₦ 123,200
#     </div>
#     <div class="s-prc-w">
#      <div class="old">
#       ₦ 130,000
#      </div>
#      <div class="bdg _dsct _sm">
#       5%
#      </div>
#     </div>
#     <div class="rev">
#      <div class="stars _s">
#       4.2 out of 5
#       <div class="in" style="width:84%">
#       </div>
#      </div>
#      (17)
#     </div>
#     <svg aria-label="Express Shipping" class="ic xprss" height="10" viewBox="0 0 114 12" width="94">
#      <use xlink:href="https://www.jumia.com.ng/assets_he/images/i-shop-jumia.9f5451c7.svg#express">
#      </use>
#     </svg>
#    </div>
#   </a>
#   <footer class="ft">
#    <form action="/cart/products/XI363MP3TS0D7NAFAMZ-384535206/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="XIAOMI" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="335380" data-dimension26="17" data-dimension27="4.2" data-dimension28="1" data-dimension37="0" data-dimension43="CP_13|FDYJE|JF23|JF23_01|JMALL" data-dimension44="0" data-id="XI363MP3TS0D7NAFAMZ" data-name='Redmi 12 6.79" 8GB RAM/256 GB ROM Android 13-Midnight Black' data-price="146.48" data-simplesku="XI363MP3TS0D7NAFAMZ-384535206" data-sku="XI363MP3TS0D7NAFAMZ" data-svar="XI363MP3TS0D7NAFAMZ-384535206" data-track-onsubmit="addToCart" data-variant="" data-xhr="true" method="post">
#     <button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">
#      Add To Cart
#     </button>
#     <input name="csrfToken" type="hidden" value="cafd37c74006eac76fb94a073c1aa87f"/>
#    </form>
#   </footer>
#  </article>
#  <article class="prd _fb col c-prd">
#   <a class="core" data-brand="itel" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="407180" data-dimension26="49" data-dimension27="4.4" data-dimension28="1" data-dimension37="0" data-dimension43="CP_13|CP_UN97|FDYJE|JF23|JF23_01|JMALL|TBOOST" data-dimension44="0" data-id="IT724MP4J5R36NAFAMZ" data-list="" data-name='P40 6.6" 4GB RAM/64GB ROM Android 12 - Black' data-position="4" data-price="62.90" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/itel-p40-6.6-4gb-ram64gb-rom-android-12-black-249754047.html">
#    <div class="img-c">
#     <img alt="" class="img" data-lazy="true" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/74/0457942/1.jpg?0731" height="208" src="..." width="208"/>
#     <span class="bdg _xs camp" style="color:#FFFFFF;background:#B177DA;">
#      Brand Festival Deal
#     </span>
#    </div>
#    <div class="info">
#     <div class="bdg _mall _xs">
#      Official Store
#     </div>
#     <h3 class="name">
#      itel P40 6.6" 4GB RAM/64GB ROM Android 12 - Black
#     </h3>
#     <div class="prc">
#      ₦ 52,900
#     </div>
#     <div class="s-prc-w">
#      <div class="old">
#       ₦ 60,200
#      </div>
#      <div class="bdg _dsct _sm">
#       12%
#      </div>
#     </div>
#     <div class="rev">
#      <div class="stars _s">
#       4.4 out of 5
#       <div class="in" style="width:88.00000000000001%">
#       </div>
#      </div>
#      (49)
#     </div>
#     <svg aria-label="Express Shipping" class="ic xprss" height="10" viewBox="0 0 114 12" width="94">
#      <use xlink:href="https://www.jumia.com.ng/assets_he/images/i-shop-jumia.9f5451c7.svg#express">
#      </use>
#     </svg>
#    </div>
#   </a>
#   <footer class="ft">
#    <form action="/cart/products/IT724MP4J5R36NAFAMZ-378676656/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="itel" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="407180" data-dimension26="49" data-dimension27="4.4" data-dimension28="1" data-dimension37="0" data-dimension43="CP_13|CP_UN97|FDYJE|JF23|JF23_01|JMALL|TBOOST" data-dimension44="0" data-id="IT724MP4J5R36NAFAMZ" data-name='P40 6.6" 4GB RAM/64GB ROM Android 12 - Black' data-price="62.90" data-simplesku="IT724MP4J5R36NAFAMZ-378676656" data-sku="IT724MP4J5R36NAFAMZ" data-svar="IT724MP4J5R36NAFAMZ-378676656" data-track-onsubmit="addToCart" data-variant="" data-xhr="true" method="post">
#     <button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">
#      Add To Cart
#     </button>
#     <input name="csrfToken" type="hidden" value="cafd37c74006eac76fb94a073c1aa87f"/>
#    </form>
#   </footer>
#  </article>
#  <article class="prd _fb col c-prd">
#   <a class="core" data-brand="Samsung" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="338501" data-dimension26="232" data-dimension27="4.2" data-dimension28="1" data-dimension37="0" data-dimension43="Boost|CARR|CFS|CP_MT149|CP_MT150|CP_UN97|DOD|FDYJE|JF23|JF23_01|JMALL|TBOOST" data-dimension44="0" data-id="SA948MP3WY8VYNAFAMZ" data-list="" data-name='Galaxy A14  6.6" 4GB RAM/128GB ROM Android 13  - Black' data-position="5" data-price="151.65" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/samsung-galaxy-a14-6.6-4gb-ram128gb-rom-android-13-black-226044763.html">
#    <div class="img-c">
#     <img alt="" class="img" data-lazy="true" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/36/7440622/1.jpg?9388" height="208" src="..." width="208"/>
#     <span class="bdg _xs camp" style="color:#FFFFFF;background:#B177DA;">
#      Brand Festival Deal
#     </span>
#    </div>
#    <div class="info">
#     <div class="bdg _mall _xs">
#      Official Store
#     </div>
#     <h3 class="name">
#      Samsung Galaxy A14  6.6" 4GB RAM/128GB ROM Android 13  - Black
#     </h3>
#     <div class="prc">
#      ₦ 127,545
#     </div>
#     <div class="s-prc-w">
#      <div class="old">
#       ₦ 138,000
#      </div>
#      <div class="bdg _dsct _sm">
#       8%
#      </div>
#     </div>
#     <div class="rev">
#      <div class="stars _s">
#       4.2 out of 5
#       <div class="in" style="width:84%">
#       </div>
#      </div>
#      (232)
#     </div>
#     <svg aria-label="Express Shipping" class="ic xprss" height="10" viewBox="0 0 114 12" width="94">
#      <use xlink:href="https://www.jumia.com.ng/assets_he/images/i-shop-jumia.9f5451c7.svg#express">
#      </use>
#     </svg>
#    </div>
#   </a>
#   <footer class="ft">
#    <form action="/cart/products/SA948MP3WY8VYNAFAMZ-346102860/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Samsung" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="338501" data-dimension26="232" data-dimension27="4.2" data-dimension28="1" data-dimension37="0" data-dimension43="Boost|CARR|CFS|CP_MT149|CP_MT150|CP_UN97|DOD|FDYJE|JF23|JF23_01|JMALL|TBOOST" data-dimension44="0" data-id="SA948MP3WY8VYNAFAMZ" data-name='Galaxy A14  6.6" 4GB RAM/128GB ROM Android 13  - Black' data-price="151.65" data-simplesku="SA948MP3WY8VYNAFAMZ-346102860" data-sku="SA948MP3WY8VYNAFAMZ" data-svar="SA948MP3WY8VYNAFAMZ-346102860" data-track-onsubmit="addToCart" data-variant="" data-xhr="true" method="post">
#     <button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">
#      Add To Cart
#     </button>
#     <input name="csrfToken" type="hidden" value="cafd37c74006eac76fb94a073c1aa87f"/>
#    </form>
#   </footer>
#  </article>
#  <article class="prd _fb col c-prd">
#   <a class="core" data-brand="itel" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="407180" data-dimension26="43" data-dimension27="4.5" data-dimension28="1" data-dimension37="0" data-dimension43="CP_13|CP_MT149|CP_MT150|CP_UN97|FDYJE|JF23|JF23_01|JMALL|TBOOST" data-dimension44="0" data-id="IT724MP4KCMAQNAFAMZ" data-list="" data-name='P40 Plus 6.6" 4GB RAM/128GB ROM Android 13 - Blue' data-position="6" data-price="80.73" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/itel-p40-plus-6.6-4gb-ram128gb-rom-android-13-blue-249754067.html">
#    <div class="img-c">
#     <img alt="" class="img" data-lazy="true" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/76/0457942/1.jpg?0823" height="208" src="..." width="208"/>
#     <span class="bdg _xs camp" style="color:#FFFFFF;background:#B177DA;">
#      Brand Festival Deal
#     </span>
#    </div>
#    <div class="info">
#     <div class="bdg _mall _xs">
#      Official Store
#     </div>
#     <h3 class="name">
#      itel P40 Plus 6.6" 4GB RAM/128GB ROM Android 13 - Blue
#     </h3>
#     <div class="prc">
#      ₦ 67,900
#     </div>
#     <div class="s-prc-w">
#      <div class="old">
#       ₦ 85,000
#      </div>
#      <div class="bdg _dsct _sm">
#       20%
#      </div>
#     </div>
#     <div class="rev">
#      <div class="stars _s">
#       4.5 out of 5
#       <div class="in" style="width:90%">
#       </div>
#      </div>
#      (43)
#     </div>
#     <svg aria-label="Express Shipping" class="ic xprss" height="10" viewBox="0 0 114 12" width="94">
#      <use xlink:href="https://www.jumia.com.ng/assets_he/images/i-shop-jumia.9f5451c7.svg#express">
#      </use>
#     </svg>
#    </div>
#   </a>
#   <footer class="ft">
#    <div class="-df -i-ctr -pr -j-bet" data-add-cart="" data-sku="IT724MP4KCMAQNAFAMZ" data-svar="IT724MP4KCMAQNAFAMZ-378676702" data-xhr="true">
#     <button class="add btn _prim -pea _md" data-trigpopup="" type="button">
#      Add To Cart
#     </button>
#    </div>
#   </footer>
#  </article>
#  <article class="prd _fb col c-prd">
#   <a class="core" data-brand="Infinix" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="362095" data-dimension26="64" data-dimension27="4.3" data-dimension28="1" data-dimension37="0" data-dimension43="CP_13|CP_MT149|CP_MT150|CP_UN97|FDYJE|JF23|JF23_01|JMALL|TBOOST|XTR250" data-dimension44="0" data-id="IN717MP4GIMAENAFAMZ" data-list="" data-name='Smart 7 HD 6.6" 2GB RAM/64GB ROM 4G Android 12 - White' data-position="7" data-price="85.61" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/infinix-smart-7-hd-6.6-2gb-ram64gb-rom-4g-android-12-white-245270696.html">
#    <div class="img-c">
#     <img alt="" class="img" data-lazy="true" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/69/6072542/1.jpg?2322" height="208" src="..." width="208"/>
#     <span class="bdg _xs camp" style="color:#FFFFFF;background:#B177DA;">
#      Brand Festival Deal
#     </span>
#    </div>
#    <div class="info">
#     <div class="bdg _mall _xs">
#      Official Store
#     </div>
#     <h3 class="name">
#      Infinix Smart 7 HD 6.6" 2GB RAM/64GB ROM 4G Android 12 - White
#     </h3>
#     <div class="prc">
#      ₦ 72,000
#     </div>
#     <div class="s-prc-w">
#      <div class="old">
#       ₦ 111,000
#      </div>
#      <div class="bdg _dsct _sm">
#       35%
#      </div>
#     </div>
#     <div class="rev">
#      <div class="stars _s">
#       4.3 out of 5
#       <div class="in" style="width:86%">
#       </div>
#      </div>
#      (64)
#     </div>
#     <svg aria-label="Express Shipping" class="ic xprss" height="10" viewBox="0 0 114 12" width="94">
#      <use xlink:href="https://www.jumia.com.ng/assets_he/images/i-shop-jumia.9f5451c7.svg#express">
#      </use>
#     </svg>
#    </div>
#   </a>
#   <footer class="ft">
#    <form action="/cart/products/IN717MP4GIMAENAFAMZ-373380700/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Infinix" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="362095" data-dimension26="64" data-dimension27="4.3" data-dimension28="1" data-dimension37="0" data-dimension43="CP_13|CP_MT149|CP_MT150|CP_UN97|FDYJE|JF23|JF23_01|JMALL|TBOOST|XTR250" data-dimension44="0" data-id="IN717MP4GIMAENAFAMZ" data-name='Smart 7 HD 6.6" 2GB RAM/64GB ROM 4G Android 12 - White' data-price="85.61" data-simplesku="IN717MP4GIMAENAFAMZ-373380700" data-sku="IN717MP4GIMAENAFAMZ" data-svar="IN717MP4GIMAENAFAMZ-373380700" data-track-onsubmit="addToCart" data-variant="" data-xhr="true" method="post">
#     <button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">
#      Add To Cart
#     </button>
#     <input name="csrfToken" type="hidden" value="cafd37c74006eac76fb94a073c1aa87f"/>
#    </form>
#   </footer>
#  </article>
#  <article class="prd _fb col c-prd">
#   <a class="core" data-brand="Tecno" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="370779" data-dimension26="152" data-dimension27="4.3" data-dimension28="1" data-dimension37="0" data-dimension43="Boost|CP_13|CP_UN97|FDYJE|JF23|JF23_01|JMALL|TBOOST|UND_29" data-dimension44="0" data-id="TE339MP4GA7WINAFAMZ" data-list="" data-name='Pop 7 Pro 6.6" 4GB RAM/64GB ROM Android 12 - Black' data-position="8" data-price="84.09" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/tecno-pop-7-pro-6.6-4gb-ram64gb-rom-android-12-black-226351296.html">
#    <div class="img-c">
#     <img alt="" class="img" data-lazy="true" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/69/2153622/1.jpg?5459" height="208" src="..." width="208"/>
#     <span class="bdg _xs camp" style="color:#FFFFFF;background:#B177DA;">
#      Brand Festival Deal
#     </span>
#    </div>
#    <div class="info">
#     <div class="bdg _mall _xs">
#      Official Store
#     </div>
#     <h3 class="name">
#      Tecno Pop 7 Pro 6.6" 4GB RAM/64GB ROM Android 12 - Black
#     </h3>
#     <div class="prc">
#      ₦ 70,723
#     </div>
#     <div class="s-prc-w">
#      <div class="old">
#       ₦ 121,373
#      </div>
#      <div class="bdg _dsct _sm">
#       42%
#      </div>
#     </div>
#     <div class="rev">
#      <div class="stars _s">
#       4.3 out of 5
#       <div class="in" style="width:86%">
#       </div>
#      </div>
#      (152)
#     </div>
#     <svg aria-label="Express Shipping" class="ic xprss" height="10" viewBox="0 0 114 12" width="94">
#      <use xlink:href="https://www.jumia.com.ng/assets_he/images/i-shop-jumia.9f5451c7.svg#express">
#      </use>
#     </svg>
#    </div>
#   </a>
#   <footer class="ft">
#    <form action="/cart/products/TE339MP4GA7WINAFAMZ-346527110/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Tecno" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="370779" data-dimension26="152" data-dimension27="4.3" data-dimension28="1" data-dimension37="0" data-dimension43="Boost|CP_13|CP_UN97|FDYJE|JF23|JF23_01|JMALL|TBOOST|UND_29" data-dimension44="0" data-id="TE339MP4GA7WINAFAMZ" data-name='Pop 7 Pro 6.6" 4GB RAM/64GB ROM Android 12 - Black' data-price="84.09" data-simplesku="TE339MP4GA7WINAFAMZ-346527110" data-sku="TE339MP4GA7WINAFAMZ" data-svar="TE339MP4GA7WINAFAMZ-346527110" data-track-onsubmit="addToCart" data-variant="" data-xhr="true" method="post">
#     <button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">
#      Add To Cart
#     </button>
#     <input name="csrfToken" type="hidden" value="cafd37c74006eac76fb94a073c1aa87f"/>
#    </form>
#   </footer>
#  </article>
#  <article class="prd _fb col c-prd">
#   <a class="core" data-brand="Tecno" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="370779" data-dimension26="129" data-dimension27="4.4" data-dimension28="1" data-dimension37="0" data-dimension43="Boost|CP_13|CP_MT149|CP_MT150|CP_UN97|FDYJE|JF23|JF23_01|JMALL|TBOOST|XTR250" data-dimension44="0" data-id="TE339MP3KRXFONAFAMZ" data-list="" data-name='Spark 10c 6.6" 4GB RAM/128GB ROM Android 13 - Black' data-position="9" data-price="109.98" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/tecno-spark-10c-6.6-4gb-ram128gb-rom-android-13-black-229839261.html">
#    <div class="img-c">
#     <img alt="" class="img" data-lazy="true" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/16/2938922/1.jpg?7441" height="208" src="..." width="208"/>
#     <span class="bdg _xs camp" style="color:#FFFFFF;background:#B177DA;">
#      Brand Festival Deal
#     </span>
#    </div>
#    <div class="info">
#     <div class="bdg _mall _xs">
#      Official Store
#     </div>
#     <h3 class="name">
#      Tecno Spark 10c 6.6" 4GB RAM/128GB ROM Android 13 - Black
#     </h3>
#     <div class="prc">
#      ₦ 92,500
#     </div>
#     <div class="s-prc-w">
#      <div class="old">
#       ₦ 140,980
#      </div>
#      <div class="bdg _dsct _sm">
#       34%
#      </div>
#     </div>
#     <div class="rev">
#      <div class="stars _s">
#       4.4 out of 5
#       <div class="in" style="width:88.00000000000001%">
#       </div>
#      </div>
#      (129)
#     </div>
#     <svg aria-label="Express Shipping" class="ic xprss" height="10" viewBox="0 0 114 12" width="94">
#      <use xlink:href="https://www.jumia.com.ng/assets_he/images/i-shop-jumia.9f5451c7.svg#express">
#      </use>
#     </svg>
#    </div>
#   </a>
#   <footer class="ft">
#    <form action="/cart/products/TE339MP3KRXFONAFAMZ-352968755/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Tecno" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="370779" data-dimension26="129" data-dimension27="4.4" data-dimension28="1" data-dimension37="0" data-dimension43="Boost|CP_13|CP_MT149|CP_MT150|CP_UN97|FDYJE|JF23|JF23_01|JMALL|TBOOST|XTR250" data-dimension44="0" data-id="TE339MP3KRXFONAFAMZ" data-name='Spark 10c 6.6" 4GB RAM/128GB ROM Android 13 - Black' data-price="109.98" data-simplesku="TE339MP3KRXFONAFAMZ-352968755" data-sku="TE339MP3KRXFONAFAMZ" data-svar="TE339MP3KRXFONAFAMZ-352968755" data-track-onsubmit="addToCart" data-variant="" data-xhr="true" method="post">
#     <button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">
#      Add To Cart
#     </button>
#     <input name="csrfToken" type="hidden" value="cafd37c74006eac76fb94a073c1aa87f"/>
#    </form>
#   </footer>
#  </article>
#  <article class="prd _fb col c-prd">
#   <a class="core" data-brand="Tecno" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="370779" data-dimension26="76" data-dimension27="4.6" data-dimension28="1" data-dimension37="0" data-dimension43="CP_13|CP_MT149|CP_MT150|CP_UN97|FDYJE|JF23|JF23_01|JMALL|TBOOST|UND_29" data-dimension44="0" data-id="TE339MP422S93NAFAMZ" data-list="" data-name='Camon 20 6.67" 8GB/256GB Android 13 -GlacierGlow + Free Gift' data-position="10" data-price="186.21" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/tecno-camon-20-6.67-8gb256gb-android-13-glacierglow-free-gift-236835354.html">
#    <div class="img-c">
#     <img alt="" class="img" data-lazy="true" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/45/3538632/1.jpg?0019" height="208" src="..." width="208"/>
#     <span class="bdg _xs camp" style="color:#FFFFFF;background:#B177DA;">
#      Brand Festival Deal
#     </span>
#    </div>
#    <div class="info">
#     <div class="bdg _mall _xs">
#      Official Store
#     </div>
#     <h3 class="name">
#      Tecno Camon 20 6.67" 8GB/256GB Android 13 -GlacierGlow + Free Gift
#     </h3>
#     <div class="prc">
#      ₦ 156,615
#     </div>
#     <div class="s-prc-w">
#      <div class="old">
#       ₦ 270,800
#      </div>
#      <div class="bdg _dsct _sm">
#       42%
#      </div>
#     </div>
#     <div class="rev">
#      <div class="stars _s">
#       4.6 out of 5
#       <div class="in" style="width:91.99999999999999%">
#       </div>
#      </div>
#      (76)
#     </div>
#     <svg aria-label="Express Shipping" class="ic xprss" height="10" viewBox="0 0 114 12" width="94">
#      <use xlink:href="https://www.jumia.com.ng/assets_he/images/i-shop-jumia.9f5451c7.svg#express">
#      </use>
#     </svg>
#    </div>
#   </a>
#   <footer class="ft">
#    <form action="/cart/products/TE339MP422S93NAFAMZ-362265261/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Tecno" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="370779" data-dimension26="76" data-dimension27="4.6" data-dimension28="1" data-dimension37="0" data-dimension43="CP_13|CP_MT149|CP_MT150|CP_UN97|FDYJE|JF23|JF23_01|JMALL|TBOOST|UND_29" data-dimension44="0" data-id="TE339MP422S93NAFAMZ" data-name='Camon 20 6.67" 8GB/256GB Android 13 -GlacierGlow + Free Gift' data-price="186.21" data-simplesku="TE339MP422S93NAFAMZ-362265261" data-sku="TE339MP422S93NAFAMZ" data-svar="TE339MP422S93NAFAMZ-362265261" data-track-onsubmit="addToCart" data-variant="" data-xhr="true" method="post">
#     <button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">
#      Add To Cart
#     </button>
#     <input name="csrfToken" type="hidden" value="cafd37c74006eac76fb94a073c1aa87f"/>
#    </form>
#   </footer>
#  </article>
#  <article class="prd _fb col c-prd">
#   <a class="core" data-brand="Infinix" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="362095" data-dimension26="86" data-dimension27="4.4" data-dimension28="1" data-dimension37="0" data-dimension43="Boost|CP_13|CP_MT149|CP_MT150|CP_UN97|FDYJE|JF23|JF23_01|JMALL|TBOOST|UND_29|XTR250" data-dimension44="0" data-id="IN717MP3EBW70NAFAMZ" data-list="" data-name='Hot 30i 6.6" 4GB RAM/128GB ROM Android 12 - Blue' data-position="11" data-price="110.58" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/infinix-hot-30i-6.6-4gb-ram128gb-rom-android-12-blue-229086450.html">
#    <div class="img-c">
#     <img alt="" class="img" data-lazy="true" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/05/4680922/1.jpg?8558" height="208" src="..." width="208"/>
#     <span class="bdg _xs camp" style="color:#FFFFFF;background:#B177DA;">
#      Brand Festival Deal
#     </span>
#    </div>
#    <div class="info">
#     <div class="bdg _mall _xs">
#      Official Store
#     </div>
#     <h3 class="name">
#      Infinix Hot 30i 6.6" 4GB RAM/128GB ROM Android 12 - Blue
#     </h3>
#     <div class="prc">
#      ₦ 93,000
#     </div>
#     <div class="s-prc-w">
#      <div class="old">
#       ₦ 186,300
#      </div>
#      <div class="bdg _dsct _sm">
#       50%
#      </div>
#     </div>
#     <div class="rev">
#      <div class="stars _s">
#       4.4 out of 5
#       <div class="in" style="width:88.00000000000001%">
#       </div>
#      </div>
#      (86)
#     </div>
#     <svg aria-label="Express Shipping" class="ic xprss" height="10" viewBox="0 0 114 12" width="94">
#      <use xlink:href="https://www.jumia.com.ng/assets_he/images/i-shop-jumia.9f5451c7.svg#express">
#      </use>
#     </svg>
#    </div>
#   </a>
#   <footer class="ft">
#    <div class="-df -i-ctr -pr -j-bet" data-add-cart="" data-sku="IN717MP3EBW70NAFAMZ" data-svar="IN717MP3EBW70NAFAMZ-351542490" data-xhr="true">
#     <button class="add btn _prim -pea _md" data-trigpopup="" type="button">
#      Add To Cart
#     </button>
#    </div>
#   </footer>
#  </article>
#  <article class="prd _fb col c-prd">
#   <a class="core" data-brand="Oppo" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="143865" data-dimension26="53" data-dimension27="3.7" data-dimension28="1" data-dimension37="0" data-dimension43="CP_13|CP_MT149|CP_MT150|CP_UN97|FDYJE|JF23|JF23_01" data-dimension44="0" data-id="OP896MP49RSC3NAFAMZ" data-list="" data-name='Refurbished OPPO  F7 6.2 "FHD+   6GB+128GB ,  Black' data-position="12" data-price="54.68" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/oppo-refurbished-oppo-f7-6.2-fhd-6gb128gb-black-238677285.html">
#    <div class="img-c">
#     <img alt="" class="img" data-lazy="true" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/58/2776832/1.jpg?2898" height="208" src="..." width="208"/>
#     <span class="bdg _xs camp" style="color:#FFFFFF;background:#B177DA;">
#      Brand Festival Deal
#     </span>
#    </div>
#    <div class="info">
#     <h3 class="name">
#      Oppo Refurbished OPPO  F7 6.2 "FHD+   6GB+128GB ,  Black
#     </h3>
#     <div class="prc">
#      ₦ 45,990
#     </div>
#     <div class="s-prc-w">
#      <div class="old">
#       ₦ 89,990
#      </div>
#      <div class="bdg _dsct _sm">
#       49%
#      </div>
#     </div>
#     <div class="rev">
#      <div class="stars _s">
#       3.7 out of 5
#       <div class="in" style="width:74%">
#       </div>
#      </div>
#      (53)
#     </div>
#     <svg aria-label="Express Shipping" class="ic xprss" height="10" viewBox="0 0 114 12" width="94">
#      <use xlink:href="https://www.jumia.com.ng/assets_he/images/i-shop-jumia.9f5451c7.svg#express">
#      </use>
#     </svg>
#    </div>
#   </a>
#   <footer class="ft">
#    <form action="/cart/products/OP896MP49RSC3NAFAMZ-364789224/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Oppo" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="143865" data-dimension26="53" data-dimension27="3.7" data-dimension28="1" data-dimension37="0" data-dimension43="CP_13|CP_MT149|CP_MT150|CP_UN97|FDYJE|JF23|JF23_01" data-dimension44="0" data-id="OP896MP49RSC3NAFAMZ" data-name='Refurbished OPPO  F7 6.2 "FHD+   6GB+128GB ,  Black' data-price="54.68" data-simplesku="OP896MP49RSC3NAFAMZ-364789224" data-sku="OP896MP49RSC3NAFAMZ" data-svar="OP896MP49RSC3NAFAMZ-364789224" data-track-onsubmit="addToCart" data-variant="" data-xhr="true" method="post">
#     <button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">
#      Add To Cart
#     </button>
#     <input name="csrfToken" type="hidden" value="cafd37c74006eac76fb94a073c1aa87f"/>
#    </form>
#   </footer>
#  </article>
#  <article class="prd _fb col c-prd">
#   <a class="core" data-brand="itel" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="407180" data-dimension26="2" data-dimension27="5" data-dimension28="1" data-dimension37="0" data-dimension43="CP_13|CP_MT149|CP_MT150|FDYJE|JF23|JF23_01|JMALL" data-dimension44="0" data-id="IT724MP4G2E63NAFAMZ" data-list="" data-name='A60s 6.6"HD 4GB RAM/128GB ROM Android 12 - Green' data-position="13" data-price="67.93" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/itel-a60s-6.6hd-4gb-ram128gb-rom-android-12-green-253205886.html">
#    <div class="img-c">
#     <img alt="" class="img" data-lazy="true" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/68/8502352/1.jpg?3933" height="208" src="..." width="208"/>
#     <span class="bdg _xs camp" style="color:#FFFFFF;background:#B177DA;">
#      Brand Festival Deal
#     </span>
#    </div>
#    <div class="info">
#     <div class="bdg _mall _xs">
#      Official Store
#     </div>
#     <h3 class="name">
#      itel A60s 6.6"HD 4GB RAM/128GB ROM Android 12 - Green
#     </h3>
#     <div class="prc">
#      ₦ 57,130
#     </div>
#     <div class="s-prc-w">
#      <div class="old">
#       ₦ 75,000
#      </div>
#      <div class="bdg _dsct _sm">
#       24%
#      </div>
#     </div>
#     <div class="rev">
#      <div class="stars _s">
#       5 out of 5
#       <div class="in" style="width:100%">
#       </div>
#      </div>
#      (2)
#     </div>
#     <svg aria-label="Express Shipping" class="ic xprss" height="10" viewBox="0 0 114 12" width="94">
#      <use xlink:href="https://www.jumia.com.ng/assets_he/images/i-shop-jumia.9f5451c7.svg#express">
#      </use>
#     </svg>
#    </div>
#   </a>
#   <footer class="ft">
#    <div class="-df -i-ctr -pr -j-bet" data-add-cart="" data-sku="IT724MP4G2E63NAFAMZ" data-svar="IT724MP4G2E63NAFAMZ-384492412" data-xhr="true">
#     <button class="add btn _prim -pea _md" data-trigpopup="" type="button">
#      Add To Cart
#     </button>
#    </div>
#   </footer>
#  </article>
#  <article class="prd _fb col c-prd">
#   <a class="core" data-brand="Infinix" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="362095" data-dimension26="78" data-dimension27="4.2" data-dimension28="1" data-dimension37="0" data-dimension43="Boost|CP_13|CP_MT149|CP_MT150|CP_UN97|FDYJE|JF23|JF23_01|JMALL|TBOOST" data-dimension44="0" data-id="IN717MP3LD8SENAFAMZ" data-list="" data-name='Smart 7 Plus 6.6" 4GB RAM/64GB ROM Android 12 - Green' data-position="14" data-price="87.02" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/infinix-smart-7-plus-6.6-4gb-ram64gb-rom-android-12-green-228388271.html">
#    <div class="img-c">
#     <img alt="" class="img" data-lazy="true" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/17/2883822/1.jpg?5245" height="208" src="..." width="208"/>
#     <span class="bdg _xs camp" style="color:#FFFFFF;background:#B177DA;">
#      Brand Festival Deal
#     </span>
#    </div>
#    <div class="info">
#     <div class="bdg _mall _xs">
#      Official Store
#     </div>
#     <h3 class="name">
#      Infinix Smart 7 Plus 6.6" 4GB RAM/64GB ROM Android 12 - Green
#     </h3>
#     <div class="prc">
#      ₦ 73,186
#     </div>
#     <div class="s-prc-w">
#      <div class="old">
#       ₦ 120,935
#      </div>
#      <div class="bdg _dsct _sm">
#       39%
#      </div>
#     </div>
#     <div class="rev">
#      <div class="stars _s">
#       4.2 out of 5
#       <div class="in" style="width:84%">
#       </div>
#      </div>
#      (78)
#     </div>
#     <svg aria-label="Express Shipping" class="ic xprss" height="10" viewBox="0 0 114 12" width="94">
#      <use xlink:href="https://www.jumia.com.ng/assets_he/images/i-shop-jumia.9f5451c7.svg#express">
#      </use>
#     </svg>
#    </div>
#   </a>
#   <footer class="ft">
#    <div class="-df -i-ctr -pr -j-bet" data-add-cart="" data-sku="IN717MP3LD8SENAFAMZ" data-svar="IN717MP3LD8SENAFAMZ-350235698" data-xhr="true">
#     <button class="add btn _prim -pea _md" data-trigpopup="" type="button">
#      Add To Cart
#     </button>
#    </div>
#   </footer>
#  </article>
#  <article class="prd _fb col c-prd">
#   <a class="core" data-brand="itel" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="15549" data-dimension26="100" data-dimension27="3.9" data-dimension28="1" data-dimension37="0" data-dimension43="Boost|CP_13|CP_MT149|CP_MT150|CP_UN97|FDYJE|JF23|JF23_01|JMALL|TBOOST" data-dimension44="0" data-id="IT724MP3LNYK4NAFAMZ" data-list="" data-name='A18 5.0" 1GB RAM/32GB ROM Android 11 - Morion Grey' data-position="15" data-price="43.34" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/itel-a18-5.0-1gb-ram32gb-rom-android-11-morion-grey-204388771.html">
#    <div class="img-c">
#     <img alt="" class="img" data-lazy="true" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/17/7883402/1.jpg?4641" height="208" src="..." width="208"/>
#     <span class="bdg _xs camp" style="color:#FFFFFF;background:#B177DA;">
#      Brand Festival Deal
#     </span>
#    </div>
#    <div class="info">
#     <div class="bdg _mall _xs">
#      Official Store
#     </div>
#     <h3 class="name">
#      itel A18 5.0" 1GB RAM/32GB ROM Android 11 - Morion Grey
#     </h3>
#     <div class="prc">
#      ₦ 36,450
#     </div>
#     <div class="s-prc-w">
#      <div class="old">
#       ₦ 40,000
#      </div>
#      <div class="bdg _dsct _sm">
#       9%
#      </div>
#     </div>
#     <div class="rev">
#      <div class="stars _s">
#       3.9 out of 5
#       <div class="in" style="width:78%">
#       </div>
#      </div>
#      (100)
#     </div>
#     <svg aria-label="Express Shipping" class="ic xprss" height="10" viewBox="0 0 114 12" width="94">
#      <use xlink:href="https://www.jumia.com.ng/assets_he/images/i-shop-jumia.9f5451c7.svg#express">
#      </use>
#     </svg>
#    </div>
#   </a>
#   <footer class="ft">
#    <form action="/cart/products/IT724MP3LNYK4NAFAMZ-316821442/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="itel" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="15549" data-dimension26="100" data-dimension27="3.9" data-dimension28="1" data-dimension37="0" data-dimension43="Boost|CP_13|CP_MT149|CP_MT150|CP_UN97|FDYJE|JF23|JF23_01|JMALL|TBOOST" data-dimension44="0" data-id="IT724MP3LNYK4NAFAMZ" data-name='A18 5.0" 1GB RAM/32GB ROM Android 11 - Morion Grey' data-price="43.34" data-simplesku="IT724MP3LNYK4NAFAMZ-316821442" data-sku="IT724MP3LNYK4NAFAMZ" data-svar="IT724MP3LNYK4NAFAMZ-316821442" data-track-onsubmit="addToCart" data-variant="" data-xhr="true" method="post">
#     <button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">
#      Add To Cart
#     </button>
#     <input name="csrfToken" type="hidden" value="cafd37c74006eac76fb94a073c1aa87f"/>
#    </form>
#   </footer>
#  </article>
#  <article class="prd _fb col c-prd">
#   <a class="core" data-brand="Renewed" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/iOS Phones" data-dimension23="304501" data-dimension26="50" data-dimension27="4.1" data-dimension28="1" data-dimension37="0" data-dimension43="Boost|CP_13|CP_MT149|CP_MT150|CP_UN97|FDYJE|JF23|JF23_01|TBOOST" data-dimension44="0" data-id="AP044MP36H0CCNAFAMZ" data-list="" data-name="IPhone X 3GB RAM+64GB (Renewed) -White" data-position="16" data-price="222.34" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/renewed-iphone-x-3gb-ram64gb-renewed-white-102896229.html">
#    <div class="img-c">
#     <img alt="" class="img" data-lazy="true" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/92/2698201/1.jpg?5628" height="208" src="..." width="208"/>
#     <span class="bdg _xs camp" style="color:#FFFFFF;background:#B177DA;">
#      Brand Festival Deal
#     </span>
#    </div>
#    <div class="info">
#     <h3 class="name">
#      IPhone X 3GB RAM+64GB (Renewed) -White
#     </h3>
#     <div class="prc">
#      ₦ 187,000
#     </div>
#     <div class="s-prc-w">
#      <div class="old">
#       ₦ 319,608
#      </div>
#      <div class="bdg _dsct _sm">
#       41%
#      </div>
#     </div>
#     <div class="rev">
#      <div class="stars _s">
#       4.1 out of 5
#       <div class="in" style="width:81.99999999999999%">
#       </div>
#      </div>
#      (50)
#     </div>
#     <svg aria-label="Express Shipping" class="ic xprss" height="10" viewBox="0 0 114 12" width="94">
#      <use xlink:href="https://www.jumia.com.ng/assets_he/images/i-shop-jumia.9f5451c7.svg#express">
#      </use>
#     </svg>
#    </div>
#   </a>
#   <footer class="ft">
#    <form action="/cart/products/AP044MP36H0CCNAFAMZ-140690947/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Renewed" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/iOS Phones" data-dimension23="304501" data-dimension26="50" data-dimension27="4.1" data-dimension28="1" data-dimension37="0" data-dimension43="Boost|CP_13|CP_MT149|CP_MT150|CP_UN97|FDYJE|JF23|JF23_01|TBOOST" data-dimension44="0" data-id="AP044MP36H0CCNAFAMZ" data-name="IPhone X 3GB RAM+64GB (Renewed) -White" data-price="222.34" data-simplesku="AP044MP36H0CCNAFAMZ-140690947" data-sku="AP044MP36H0CCNAFAMZ" data-svar="AP044MP36H0CCNAFAMZ-140690947" data-track-onsubmit="addToCart" data-variant="" data-xhr="true" method="post">
#     <button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">
#      Add To Cart
#     </button>
#     <input name="csrfToken" type="hidden" value="cafd37c74006eac76fb94a073c1aa87f"/>
#    </form>
#   </footer>
#  </article>
#  <article class="prd _fb col c-prd">
#   <a class="core" data-brand="Samsung" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="338501" data-dimension26="138" data-dimension27="4.5" data-dimension28="1" data-dimension37="0" data-dimension43="Boost|CARR|CP_13|CP_MT149|CP_MT150|CP_UN97|DOD|FDYJE|INV_CLEAR|JF23|JF23_01|JMALL|TBOOST|UND_29" data-dimension44="0" data-id="SA948MP4OEBVINAFAMZ" data-list="" data-name='Galaxy A14 6.6" 4GB RAM/64GB ROM Android 13 - Black' data-position="17" data-price="144.49" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/samsung-galaxy-a14-6.6-4gb-ram64gb-rom-android-13-black-226044828.html">
#    <div class="img-c">
#     <img alt="" class="img" data-lazy="true" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/82/8440622/1.jpg?2300" height="208" src="..." width="208"/>
#     <span class="bdg _xs camp" style="color:#FFFFFF;background:#B177DA;">
#      Brand Festival Deal
#     </span>
#    </div>
#    <div class="info">
#     <div class="bdg _mall _xs">
#      Official Store
#     </div>
#     <h3 class="name">
#      Samsung Galaxy A14 6.6" 4GB RAM/64GB ROM Android 13 - Black
#     </h3>
#     <div class="prc">
#      ₦ 121,520
#     </div>
#     <div class="s-prc-w">
#      <div class="old">
#       ₦ 135,000
#      </div>
#      <div class="bdg _dsct _sm">
#       10%
#      </div>
#     </div>
#     <div class="rev">
#      <div class="stars _s">
#       4.5 out of 5
#       <div class="in" style="width:90%">
#       </div>
#      </div>
#      (138)
#     </div>
#     <svg aria-label="Express Shipping" class="ic xprss" height="10" viewBox="0 0 114 12" width="94">
#      <use xlink:href="https://www.jumia.com.ng/assets_he/images/i-shop-jumia.9f5451c7.svg#express">
#      </use>
#     </svg>
#    </div>
#   </a>
#   <footer class="ft">
#    <form action="/cart/products/SA948MP4OEBVINAFAMZ-346102963/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Samsung" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="338501" data-dimension26="138" data-dimension27="4.5" data-dimension28="1" data-dimension37="0" data-dimension43="Boost|CARR|CP_13|CP_MT149|CP_MT150|CP_UN97|DOD|FDYJE|INV_CLEAR|JF23|JF23_01|JMALL|TBOOST|UND_29" data-dimension44="0" data-id="SA948MP4OEBVINAFAMZ" data-name='Galaxy A14 6.6" 4GB RAM/64GB ROM Android 13 - Black' data-price="144.49" data-simplesku="SA948MP4OEBVINAFAMZ-346102963" data-sku="SA948MP4OEBVINAFAMZ" data-svar="SA948MP4OEBVINAFAMZ-346102963" data-track-onsubmit="addToCart" data-variant="" data-xhr="true" method="post">
#     <button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">
#      Add To Cart
#     </button>
#     <input name="csrfToken" type="hidden" value="cafd37c74006eac76fb94a073c1aa87f"/>
#    </form>
#   </footer>
#  </article>
#  <article class="prd _fb col c-prd">
#   <a class="core" data-brand="XIAOMI" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="227251" data-dimension26="30" data-dimension27="4.6" data-dimension28="1" data-dimension37="0" data-dimension43="CP_13|CP_UN97|FDYJE|JF23|JF23_01|JMALL" data-dimension44="0" data-id="XI363MP3P06X1NAFAMZ" data-list="" data-name='Redmi A2+ 6.52" 2GB RAM/32GB ROM Android 12 - Light Blue' data-position="18" data-price="56.95" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/xiaomi-redmi-a2-6.52-2gb-ram32gb-rom-android-12-light-blue-239879332.html">
#    <div class="img-c">
#     <img alt="" class="img" data-lazy="true" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/23/3978932/1.jpg?3232" height="208" src="..." width="208"/>
#     <span class="bdg _xs camp" style="color:#FFFFFF;background:#B177DA;">
#      Brand Festival Deal
#     </span>
#    </div>
#    <div class="info">
#     <div class="bdg _mall _xs">
#      Official Store
#     </div>
#     <h3 class="name">
#      XIAOMI Redmi A2+ 6.52" 2GB RAM/32GB ROM Android 12 - Light Blue
#     </h3>
#     <div class="prc">
#      ₦ 47,900
#     </div>
#     <div class="s-prc-w">
#      <div class="old">
#       ₦ 69,000
#      </div>
#      <div class="bdg _dsct _sm">
#       31%
#      </div>
#     </div>
#     <div class="rev">
#      <div class="stars _s">
#       4.6 out of 5
#       <div class="in" style="width:91.99999999999999%">
#       </div>
#      </div>
#      (30)
#     </div>
#     <svg aria-label="Express Shipping" class="ic xprss" height="10" viewBox="0 0 114 12" width="94">
#      <use xlink:href="https://www.jumia.com.ng/assets_he/images/i-shop-jumia.9f5451c7.svg#express">
#      </use>
#     </svg>
#    </div>
#   </a>
#   <footer class="ft">
#    <form action="/cart/products/XI363MP3P06X1NAFAMZ-366475398/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="XIAOMI" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="227251" data-dimension26="30" data-dimension27="4.6" data-dimension28="1" data-dimension37="0" data-dimension43="CP_13|CP_UN97|FDYJE|JF23|JF23_01|JMALL" data-dimension44="0" data-id="XI363MP3P06X1NAFAMZ" data-name='Redmi A2+ 6.52" 2GB RAM/32GB ROM Android 12 - Light Blue' data-price="56.95" data-simplesku="XI363MP3P06X1NAFAMZ-366475398" data-sku="XI363MP3P06X1NAFAMZ" data-svar="XI363MP3P06X1NAFAMZ-366475398" data-track-onsubmit="addToCart" data-variant="" data-xhr="true" method="post">
#     <button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">
#      Add To Cart
#     </button>
#     <input name="csrfToken" type="hidden" value="cafd37c74006eac76fb94a073c1aa87f"/>
#    </form>
#   </footer>
#  </article>
#  <article class="prd _fb col c-prd">
#   <a class="core" data-brand="Kuhl" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="368221" data-dimension26="16" data-dimension27="3.8" data-dimension28="1" data-dimension37="0" data-dimension43="CP_13|CP_MT149|CP_MT150|CP_UN97|FDYJE|JF23|JF23_01" data-dimension44="0" data-id="KU348MP3EPM0UNAFAMZ" data-list="" data-name="14Pro Max 6.82FHD,4GB+64GB, 5mp+13mp, 5000 MA Battery Black" data-position="19" data-price="71.33" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/kuhl-14pro-max-6.82fhd4gb64gb-5mp13mp-5000-ma-battery-black-249080160.html">
#    <div class="img-c">
#     <img alt="" class="img" data-lazy="true" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/06/1080942/1.jpg?8253" height="208" src="..." width="208"/>
#     <span class="bdg _xs camp" style="color:#FFFFFF;background:#B177DA;">
#      Brand Festival Deal
#     </span>
#    </div>
#    <div class="info">
#     <h3 class="name">
#      Kuhl 14Pro Max 6.82FHD,4GB+64GB, 5mp+13mp, 5000 MA Battery Black
#     </h3>
#     <div class="prc">
#      ₦ 59,990
#     </div>
#     <div class="s-prc-w">
#      <div class="old">
#       ₦ 69,990
#      </div>
#      <div class="bdg _dsct _sm">
#       14%
#      </div>
#     </div>
#     <div class="rev">
#      <div class="stars _s">
#       3.8 out of 5
#       <div class="in" style="width:76%">
#       </div>
#      </div>
#      (16)
#     </div>
#     <svg aria-label="Express Shipping" class="ic xprss" height="10" viewBox="0 0 114 12" width="94">
#      <use xlink:href="https://www.jumia.com.ng/assets_he/images/i-shop-jumia.9f5451c7.svg#express">
#      </use>
#     </svg>
#    </div>
#   </a>
#   <footer class="ft">
# ...
#     <button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">
#      Add To Cart
#     </button>
#     <input name="csrfToken" type="hidden" value="cafd37c74006eac76fb94a073c1aa87f"/>
#    </form>
#   </footer>
#  </article>
#  <article class="prd _fb col c-prd">
#   <a class="core" data-brand="Renewed" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="390487" data-dimension26="14" data-dimension27="4.2" data-dimension28="1" data-dimension37="0" data-dimension43="CP_13|CP_MT149|CP_MT150|CP_UN97|FDYJE" data-dimension44="0" data-id="OP896MP4FDKK2NAFAMZ" data-list="" data-name='Refurbished OPPO F11 6.53" Full HD Display 6GB+128GB 48MP Dual Camera 4020mAh Battery 4G LTE Smartphone' data-position="39" data-price="59.44" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/renewed-refurbished-oppo-f11-6.53-full-hd-display-6gb128gb-48mp-dual-camera-4020mah-battery-4g-lte-smartphone-241129676.html">
#    <div class="img-c">
#     <img alt="" class="img" data-lazy="true" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/67/6921142/1.jpg?5542" height="208" src="..." width="208"/>
#     <img alt="FDYJE" class="_ni camp" data-lazy="true" data-src="https://ng.jumia.is/badges/fdyje/3/138x18.png?8589" src="..."/>
#    </div>
#    <div class="info">
#     <h3 class="name">
#      Refurbished OPPO F11 6.53" Full HD Display 6GB+128GB 48MP Dual Camera 4020mAh Battery 4G LTE Smartphone
#     </h3>
#     <div class="prc">
#      ₦ 49,990
#     </div>
#     <div class="s-prc-w">
#      <div class="old">
#       ₦ 119,980
#      </div>
#      <div class="bdg _dsct _sm">
#       58%
#      </div>
#     </div>
#     <div class="rev">
#      <div class="stars _s">
#       4.2 out of 5
#       <div class="in" style="width:84%">
#       </div>
#      </div>
#      (14)
#     </div>
#     <svg aria-label="Express Shipping" class="ic xprss" height="10" viewBox="0 0 114 12" width="94">
#      <use xlink:href="https://www.jumia.com.ng/assets_he/images/i-shop-jumia.9f5451c7.svg#express">
#      </use>
#     </svg>
#    </div>
#   </a>
#   <footer class="ft">
#    <form action="/cart/products/OP896MP4FDKK2NAFAMZ-368391455/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Renewed" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="390487" data-dimension26="14" data-dimension27="4.2" data-dimension28="1" data-dimension37="0" data-dimension43="CP_13|CP_MT149|CP_MT150|CP_UN97|FDYJE" data-dimension44="0" data-id="OP896MP4FDKK2NAFAMZ" data-name='Refurbished OPPO F11 6.53" Full HD Display 6GB+128GB 48MP Dual Camera 4020mAh Battery 4G LTE Smartphone' data-price="59.44" data-simplesku="OP896MP4FDKK2NAFAMZ-368391455" data-sku="OP896MP4FDKK2NAFAMZ" data-svar="OP896MP4FDKK2NAFAMZ-368391455" data-track-onsubmit="addToCart" data-variant="" data-xhr="true" method="post">
#     <button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">
#      Add To Cart
#     </button>
#     <input name="csrfToken" type="hidden" value="cafd37c74006eac76fb94a073c1aa87f"/>
#    </form>
#   </footer>
#  </article>
#  <article class="prd _fb col c-prd">
#   <a class="core" data-brand="Tecno" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="15549" data-dimension26="105" data-dimension27="4.2" data-dimension28="1" data-dimension37="0" data-dimension43="Boost|CP_13|CP_MT149|CP_MT150|CP_UN97|FDYJE|JF23|JF23_01|JMALL|TBOOST" data-dimension44="0" data-id="TE339MP3K3R5FNAFAMZ" data-list="" data-name='POP 7(BF6) 6.6" HD+ 2GB RAM/64GB ROM Android 12 - Capri Blue' data-position="40" data-price="79.48" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/tecno-pop-7bf6-6.6-hd-2gb-ram64gb-rom-android-12-capri-blue-230066151.html">
#    <div class="img-c">
#     <img alt="" class="img" data-lazy="true" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/15/1660032/1.jpg?1375" height="208" src="..." width="208"/>
#     <span class="bdg _xs camp" style="color:#FFFFFF;background:#B177DA;">
#      Brand Festival Deal
#     </span>
#    </div>
#    <div class="info">
#     <div class="bdg _mall _xs">
#      Official Store
#     </div>
#     <h3 class="name">
#      Tecno POP 7(BF6) 6.6" HD+ 2GB RAM/64GB ROM Android 12 - Capri Blue
#     </h3>
#     <div class="prc">
#      ₦ 66,850
#     </div>
#     <div class="s-prc-w">
#      <div class="old">
#       ₦ 90,000
#      </div>
#      <div class="bdg _dsct _sm">
#       26%
#      </div>
#     </div>
#     <div class="rev">
#      <div class="stars _s">
#       4.2 out of 5
#       <div class="in" style="width:84%">
#       </div>
#      </div>
#      (105)
#     </div>
#     <svg aria-label="Express Shipping" class="ic xprss" height="10" viewBox="0 0 114 12" width="94">
#      <use xlink:href="https://www.jumia.com.ng/assets_he/images/i-shop-jumia.9f5451c7.svg#express">
#      </use>
#     </svg>
#    </div>
#   </a>
#   <footer class="ft">
#    <form action="/cart/products/TE339MP3K3R5FNAFAMZ-353510308/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Tecno" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="15549" data-dimension26="105" data-dimension27="4.2" data-dimension28="1" data-dimension37="0" data-dimension43="Boost|CP_13|CP_MT149|CP_MT150|CP_UN97|FDYJE|JF23|JF23_01|JMALL|TBOOST" data-dimension44="0" data-id="TE339MP3K3R5FNAFAMZ" data-name='POP 7(BF6) 6.6" HD+ 2GB RAM/64GB ROM Android 12 - Capri Blue' data-price="79.48" data-simplesku="TE339MP3K3R5FNAFAMZ-353510308" data-sku="TE339MP3K3R5FNAFAMZ" data-svar="TE339MP3K3R5FNAFAMZ-353510308" data-track-onsubmit="addToCart" data-variant="" data-xhr="true" method="post">
#     <button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">
#      Add To Cart
#     </button>
#     <input name="csrfToken" type="hidden" value="cafd37c74006eac76fb94a073c1aa87f"/>
#    </form>
#   </footer>
#  </article>
# </div>
#
# End
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# C:\Users\user0011\AppData\Local\Temp\ipykernel_11528\917650937.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)

# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
import requests
url = "https://hotels.ng/hotels-in-lagos"
page = requests.get(url)
soup = bs(page.content, "html5lib")
#print(soup.prettify())
table = soup.find("div",attrs={"class":"col-xs-12 col-sm-8 row listing-hotels-details-box"})
print(table.prettify())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 9
#       7 #print(soup.prettify())
#       8 table = soup.findAll("div",attrs={"class":"col-xs-12 col-sm-8 row listing-hotels-details-box"})
# ----> 9 print(table.prettify())
#
# File ~\anaconda3\Lib\site-packages\bs4\element.py:2428, in ResultSet.__getattr__(self, key)
#    2426 def __getattr__(self, key):
#    2427     """Raise a helpful exception to explain a common code fix."""
# -> 2428     raise AttributeError(
#    2429         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2430     )
#
# AttributeError: ResultSet object has no attribute 'prettify'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
